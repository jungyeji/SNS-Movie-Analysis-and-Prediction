# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

dataset = np.loadtxt("/content/drive/My Drive/data5.csv", delimiter=",", encoding="utf-8-sig")

#data set
x_train = dataset[:94,0:6] # dataset[:700, 0:8]
y_train = dataset[:94,6] # dataset[:700, 8]
x_test = dataset[94:,0:6] # dataset[700, 0:8]
y_test = dataset[94:,6]  #dataset[700, 8]

model = Sequential()
model.add(Dense(10000, input_dim=6, activation='relu'))
model.add(Dense(10000, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='rmsprop', loss='mse')

hist = model.fit(x_train, y_train, epochs=50, batch_size=64)

## %matplotlib inline
# import matplotlib.pyplot as plt

# plt.plot(hist.history['loss'])
# plt.ylim(0.0, 1.5)
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train'], loc='upper left')
# plt.show()

loss = model.evaluate(x_test, y_test, batch_size=32)
print('loss: '+str(loss))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/50
# 94/94 [==============================] - 2s 17ms/step - loss: 11629178628313.8730
# Epoch 2/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11628377516249.8730
# Epoch 3/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11626439357374.6387
# Epoch 4/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11623368468697.8730
# Epoch 5/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11618633277962.8926
# Epoch 6/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11611907042195.0645
# Epoch 7/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11603790729303.1484
# Epoch 8/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11594552774743.1484
# Epoch 9/50
# 94/94 [==============================] - 0s 2ms/step - loss: 11583554037977.8730
# ...
